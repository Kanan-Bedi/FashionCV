# %%
import cv2
import os

def capture_and_save_image(url, save_directory):
    # Initialize webcam
    cap = cv2.VideoCapture(url)
    
    if not cap.isOpened():
        print("Error: Could not open webcam.")
        return
    
    # Capture image
    ret, frame = cap.read()
    
    if ret:
        # Create directory to save images if it doesn't exist
        if not os.path.exists(save_directory):
            os.makedirs(save_directory)
        
        # Save image
        image_path = os.path.join(save_directory, "captured_image{i+1}.jpg")
        cv2.imwrite(image_path, frame)
        print("Image captured and saved.")
        
    else:
        print("Error capturing image.")
    
    # Release webcam
    cap.release()

# Example usage:
webcam_url = 'http://10.24.79.180:8080/video'  # Change this
save_dir = 'captured_images1'

capture_and_save_image(webcam_url, save_dir)
# Out:
# Image captured and saved.

# %%
# !pip install mediapipe
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 797.4 kB/s eta 0:00:00 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.5/159.5 kB 976.9 kB/s eta 0:00:00a 0:00:01
# ...
#   Using cached sympy-1.12-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached fsspec-2024.3.1-py3-none-any.whl.metadata (6.8 kB)
# ...
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 MB 318.8 kB/s eta 0:00:0000:0100:05
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 470.7 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 408.2 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 304.1 kB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 304.2 kB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.7/66.7 MB 215.0 kB/s eta 0:00:0000:0100:08
# ...
